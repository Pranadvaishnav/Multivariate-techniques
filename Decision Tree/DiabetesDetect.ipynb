# %%
# %pip install pycaret

# %%
from pycaret.datasets import get_data
data = get_data('index')

# %%
diabetes_datasets=get_data('diabetes')

# %%
from pycaret.classification import *
exp1 = setup(data = diabetes_datasets, target = 'Class variable')

# %%
decision_tree_model = create_model('dt')

# %%
plot_model(decision_tree_model, plot='confusion_matrix')

# %%
Test_dataset = get_data('diabetes').iloc[50:70,:]
Test_dataset

# %%
new_predictions=predict_model(decision_tree_model)
new_predictions

# %% [markdown]
# save_model(decision_tree_model,"Diabetes Detection using Decision tree")
